# %% [markdown]
# # England Premier League Analysis

# %% [markdown]
# # 목차
#
# 데이터 소개
#
# 1. 토트넘 분석
#                 1. 선수단 구성
#                 2. 문제점
#                 3. 보안점(이적생) : 공격수, 미드필더
#
# 2. 실제와 게임과의 상관관계
#
# 3. 게임 능력치 만들어 보기

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.figure_factory as ff
import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import os

# %%
# 데이터 불러오기

data = pd.read_csv('/content/Football Players Stats (Premier League 2021-2022)2.csv', encoding='latin') # latin으로 해야 nation이 잘 나옴

# %%
# 데이터 확인

data.head()
# Out:
#                Player     Team   Nation    Pos   Age  MP  Starts    Min   90s  \
# 0         Bukayo Saka  Arsenal  eng ENG  FW,MF  19.0  38      36  2,978  33.1
# 1  Gabriel Dos Santos  Arsenal   br BRA     DF  23.0  35      35  3,063  34.0
# 2      Aaron Ramsdale  Arsenal  eng ENG     GK  23.0  34      34  3,060  34.0
# 3           Ben White  Arsenal  eng ENG     DF  23.0  32      32  2,880  32.0
# 4      Martin ?egaard  Arsenal   no NOR     MF  22.0  36      32  2,785  30.9
#
#     Gls  ...  npxG.1  npxG+xA.1  %SuccPress  SuccDrib  AtmpDrib  Interception  \
# 0  11.0  ...    0.25       0.46         NaN       NaN       NaN           NaN
# 1   5.0  ...    0.08       0.10         NaN       NaN       NaN           NaN
# 2   0.0  ...    0.00       0.00         NaN       NaN       NaN           NaN
# 3   0.0  ...    0.03       0.05         NaN       NaN       NaN           NaN
# 4   7.0  ...    0.16       0.38         NaN       NaN       NaN           NaN
#
#    Clearances  G-AC   Sta   PKG
# 0         NaN  71.0  76.0  61.0
# 1         NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN
#
# [5 rows x 38 columns]

# %%
# 데이터 모양 확인

data.shape
# Out:
# (691, 38)

# %%
# 데이터 정보 확인

data.info
# Out:
# <bound method DataFrame.info of                  Player                     Team   Nation    Pos   Age  MP  \
# 0           Bukayo Saka                  Arsenal  eng ENG  FW,MF  19.0  38
# 1    Gabriel Dos Santos                  Arsenal   br BRA     DF  23.0  35
# 2        Aaron Ramsdale                  Arsenal  eng ENG     GK  23.0  34
# 3             Ben White                  Arsenal  eng ENG     DF  23.0  32
# 4        Martin ?egaard                  Arsenal   no NOR     MF  22.0  36
# ..                  ...                      ...      ...    ...   ...  ..
# 686   Christian Marques  Wolverhampton Wanderers   ch SUI     DF  18.0   0
# 687     Yerson Mosquera  Wolverhampton Wanderers   co COL     DF  20.0   0
# 688       Louie Moulden  Wolverhampton Wanderers  eng ENG     GK  19.0   0
# 689      Dion Sanderson  Wolverhampton Wanderers  eng ENG     DF  21.0   0
# 690        James Storer  Wolverhampton Wanderers      NaN     GK   NaN   0
#
#      Starts    Min   90s   Gls  ...  npxG.1  npxG+xA.1  %SuccPress  SuccDrib  \
# 0        36  2,978  33.1  11.0  ...    0.25       0.46         NaN       NaN
# 1        35  3,063  34.0   5.0  ...    0.08       0.10         NaN       NaN
# 2        34  3,060  34.0   0.0  ...    0.00       0.00         NaN       NaN
# 3        32  2,880  32.0   0.0  ...    0.03       0.05         NaN       NaN
# 4        32  2,785  30.9   7.0  ...    0.16       0.38         NaN       NaN
# ..      ...    ...   ...   ...  ...     ...        ...         ...       ...
# 686       0    NaN   NaN   NaN  ...     NaN        NaN         NaN       NaN
# 687       0    NaN   NaN   NaN  ...     NaN        NaN         NaN       NaN
# 688       0    NaN   NaN   NaN  ...     NaN        NaN         NaN       NaN
# 689       0    NaN   NaN   NaN  ...     NaN        NaN         NaN       NaN
# 690       0    NaN   NaN   NaN  ...     NaN        NaN         NaN       NaN
#
#      AtmpDrib  Interception  Clearances  G-AC   Sta   PKG
# 0         NaN           NaN         NaN  71.0  76.0  61.0
# 1         NaN           NaN         NaN   NaN   NaN   NaN
# 2         NaN           NaN         NaN   NaN   NaN   NaN
# 3         NaN           NaN         NaN   NaN   NaN   NaN
# 4         NaN           NaN         NaN   NaN   NaN   NaN
# ..        ...           ...         ...   ...   ...   ...
# 686       NaN           NaN         NaN   NaN   NaN   NaN
# 687       NaN           NaN         NaN   NaN   NaN   NaN
# 688       NaN           NaN         NaN   NaN   NaN   NaN
# 689       NaN           NaN         NaN   NaN   NaN   NaN
# 690       NaN           NaN         NaN   NaN   NaN   NaN
#
# [691 rows x 38 columns]>

# %%
# 널 값 확인

data.isnull().sum()
# Out:
# Player            0
# Team              0
# Nation            3
# Pos               0
# Age               4
# MP                0
# Starts            0
# Min             145
# 90s             144
# Gls             144
# Ast             144
# G-PK            144
# PK              144
# PKatt           144
# CrdY            144
# CrdR            144
# Gls.1           145
# Ast.1           145
# G+A             145
# G-PK2           145
# G+A-PK          145
# xG              145
# npxG            145
# xA              145
# npxG+xA         145
# xG.1            145
# xA.1            145
# xG+xA           145
# npxG.1          145
# npxG+xA.1       145
# %SuccPress      686
# SuccDrib        686
# AtmpDrib        686
# Interception    686
# Clearances      686
# G-AC            671
# Sta             671
# PKG             671
# dtype: int64

# %% [markdown]
# Min이 널 값이라는 것은 출전하지 못했다는 뜻이다.
# 이 선수들은 필요 없는 데이터이기 때문에 삭제하겠다.
#
# 데이터가 바보 같아서 하나씩 밀려있는 데이터가 있었다.그래서 일일이 수정을 했었다.

# %%
data = data.dropna(subset=['Min'])

# %%
data.isnull().sum()
# Out:
# Player            0
# Team              0
# Nation            0
# Pos               0
# Age               0
# MP                0
# Starts            0
# Min               0
# 90s               0
# Gls               0
# Ast               0
# G-PK              0
# PK                0
# PKatt             0
# CrdY              0
# CrdR              0
# Gls.1             0
# Ast.1             0
# G+A               0
# G-PK2             0
# G+A-PK            0
# xG                0
# npxG              0
# xA                0
# npxG+xA           0
# xG.1              0
# xA.1              0
# xG+xA             0
# npxG.1            0
# npxG+xA.1         0
# %SuccPress      541
# SuccDrib        541
# AtmpDrib        541
# Interception    541
# Clearances      541
# G-AC            526
# Sta             526
# PKG             526
# dtype: int64

# %% [markdown]
# # 1. 토트넘 분석

# %% [markdown]
# ### 1. 선수단 구성

# %%
Tottenham = data[ data['Team'] == 'Tottenham Hotspur']

# %%
NumberofPlayers = data.groupby(pd.Grouper(key='Team')).size().reset_index(name='count')
fig = px.treemap(NumberofPlayers, path=['Team'], values='count')
fig.update_layout(title_text='Number of Players for each Club',
                  title_x=0.5, title_font=dict(size=30)
                  )
fig.update_traces(textinfo="label+value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="465934be-ed8f-4094-b581-c03083142a28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("465934be-ed8f-4094-b581-c03083142a28")) {                    Plotly.newPlot(                        "465934be-ed8f-4094-b581-c03083142a28",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Arsenal","Aston Villa","Brentford","Brighton & Hove Albion","Burnley","Chelsea","Crystal Palace","Everton","Leeds United","Leicester City","Liverpool","Manchester City","Manchester United","Newcastle United","Norwich City","Southampton","Tottenham Hotspur","Watford","West Ham United","Wolverhampton Wanderers"],"labels":["Arsenal","Aston Villa","Brentford","Brighton & Hove Albion","Burnley","Chelsea","Crystal Palace","Everton","Leeds United","Leicester City","Liverpool","Manchester City","Manchester United","Newcastle United","Norwich City","Southampton","Tottenham Hotspur","Watford","West Ham United","Wolverhampton Wanderers"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[27,31,29,26,23,26,24,33,29,28,27,26,29,29,28,25,25,30,25,26],"type":"treemap","textinfo":"label+value"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewi ...

# %% [markdown]
# 현재, EPL 사무국은 1군 선수단을 25명으로 제한하고 있다.
#
# 데이터는 겨울에 이적한 선수들을 전 소속팀과 현 소속팀 둘 다 포함하고 있다.
#
# 따라서, 에버튼은 겨울 이적을 활발히 했다는 것을 알 수 있다. 반면에, 토트넘은 아주 조용한 시즌을 보냈다.

# %%
Nationality = data.groupby(pd.Grouper(key='Nation')).size().reset_index(name='count')
fig = px.treemap(Nationality, path=['Nation'], values='count')
fig.update_layout(title_text='Nation of the League',
                  title_x=0.5, title_font=dict(size=30)
                  )
fig.update_traces(textinfo="label+value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="58bc0a4a-6b7c-4ca8-bc07-ce748f64d8a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58bc0a4a-6b7c-4ca8-bc07-ce748f64d8a5")) {                    Plotly.newPlot(                        "58bc0a4a-6b7c-4ca8-bc07-ce748f64d8a5",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["al\u00a0ALB","ao\u00a0ANG","ar\u00a0ARG","at\u00a0AUT","ba\u00a0BIH","be\u00a0BEL","bf\u00a0BFA","br\u00a0BRA","cd\u00a0COD","ch\u00a0SUI","ci\u00a0CIV","cl\u00a0CHI","cm\u00a0CMR","co\u00a0COL","cz\u00a0CZE","de\u00a0GER","dk\u00a0DEN","dz\u00a0ALG","ec\u00a0ECU","eg\u00a0EGY","eng\u00a0ENG","es\u00a0ESP","fi\u00a0FIN","fr\u00a0FRA","ga\u00a0GAB","gd\u00a0GRN","gh\u00a0GHA","gn\u00a0GUI","gr\u00a0GRE","hr\u00a0CRO","ie\u00a0IRL","ir\u00a0IRN","is\u00a0ISL","it\u00a0ITA","jm\u00a0JAM","jp\u00a0JPN","kr\u00a0KOR","ma\u00a0MAR","ml\u00a0MLI","mx\u00a0MEX","ng\u00a0NGA","nir\u00a0NIR","nl\u00a0NED","no\u00a0NOR","nz\u00a0NZL","pl\u00a0POL","pt\u00a0POR","py\u00a0PAR","rs\u00a0SRB","sct\u00a0SCO","se\u00a0SWE","sk\u00a0SVK","sn\u00a0SEN","tn\u00a0TUN","tr\u00a0TUR","ua\u00a0UKR","us\u00a0USA","uy\u00a0URU","ve\u00a0VEN","wls\u00a0WAL","xk\u00a0KVX","zm\u00a0ZAM","zw\u00a0ZIM"],"labels":["al\u00a0ALB","ao\u00a0ANG","ar\u00a0ARG","at\u00a0AUT","ba\u00a0BIH","be\u00a0BEL","bf\u00a0BFA","br\u00a0BRA","cd\u00a0COD","ch\u00a0SUI","ci\u00a0CIV","cl\u00a0CHI","cm\u00a0CMR","co\u00a0COL","cz\u00a0CZE","de\u00a0GER","dk\u00a0DEN","dz\u00a0ALG","ec\u00a0ECU","eg\u00a0EGY","eng\u00a0ENG","es\u00a0ESP","fi\u00a0FIN","fr\u00a0FRA","ga\u00a0GAB","gd\u00a0GRN","gh\u00a0GHA","gn\u00a0GUI","gr\u00a0GRE","hr\u00a0CRO","ie\u00a0IRL","ir\u00a0IRN","is\u00a0ISL","it\u00a0ITA","jm\u00a0JAM","jp\u00a0JPN","kr\u00a0KOR","ma\u00a0MAR","ml\u00a0MLI","mx\u00a0MEX","ng\u00a0NGA","nir\u00a0NIR","nl\u00a0NED","no\u00a0NOR","nz\u00a0NZL","pl\u00a0POL","pt\u00a0POR","py\u00a0PAR","rs\u00a0SRB","sct\u00a0SCO","se\u00a0SWE","sk\u00a0SVK","sn\u00a0SEN","tn\u00a0TUN","tr\u00a0TUR","ua\u00a0UKR","us\u00a0USA","uy\u00a0URU","ve\u00a0VEN","wls\u00a0WAL","xk\u00a0KVX","zm\u00a0ZAM","zw\u00a0ZIM"],"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",""],"values":[1,1,8,1,2,10,1,27,3,2,7,1,2,5,4,10,14,2,2,3,199,30,2,31,1,1,6,1,3,2,14,1,1,4,3,2,2,4,3,1,9,5,16,7,2,6,21,1,2,16,7,2,5,1,4,3,3,2,1,12,1,2,1],"type":"treemap","textinfo":"label+value"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"c ...

# %% [markdown]
# 영국 리그니깐 영국사람이 제일 많았다.
#
# 그리고 전통적인 축구 강호 프랑스, 스페인, 브라질이 그 순서를 따른다.
#
# 대한민국은 손흥민, 황희찬 단 2명. 오른쪽 밑에 조그만하게 보인다. 토트넘은 어떨까 ?

# %%
Nationality = Tottenham.groupby(pd.Grouper(key='Nation')).size().reset_index(name='count')
fig = px.treemap(Nationality, path=['Nation'], values='count')
fig.update_layout(title_text='Nation of Tottenham\'s Player',
                  title_x=0.5, title_font=dict(size=30)
                  )
fig.update_traces(textinfo="label+value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="45fc4eb1-9b08-413c-b09e-08ce39b9ced2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45fc4eb1-9b08-413c-b09e-08ce39b9ced2")) {                    Plotly.newPlot(                        "45fc4eb1-9b08-413c-b09e-08ce39b9ced2",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["ar\u00a0ARG","br\u00a0BRA","co\u00a0COL","dk\u00a0DEN","eng\u00a0ENG","es\u00a0ESP","fr\u00a0FRA","ie\u00a0IRL","kr\u00a0KOR","nl\u00a0NED","se\u00a0SWE","uy\u00a0URU","wls\u00a0WAL"],"labels":["ar\u00a0ARG","br\u00a0BRA","co\u00a0COL","dk\u00a0DEN","eng\u00a0ENG","es\u00a0ESP","fr\u00a0FRA","ie\u00a0IRL","kr\u00a0KOR","nl\u00a0NED","se\u00a0SWE","uy\u00a0URU","wls\u00a0WAL"],"name":"","parents":["","","","","","","","","","","","",""],"values":[2,2,1,1,8,2,2,1,1,1,1,1,2],"type":"treemap","textinfo":"label+value"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921" ...

# %% [markdown]
# EPL 사무국의 잉글랜드 자국민 육성 제도로 인해
#
# 한 팀에 잉글랜드 혹은 웨일즈에서 21세 전에 3년 간 훈련받은 선수가 최소 8명 필요하다.
#
# 즉, 영국선수가 8명 이상이 반드시 있어야 한다.
#
# 토트넘은 이를 잘 수행하고 있다는 것을 알 수 있다.

# %%
# 나이

plt.figure(figsize=(15, 8))
sns.distplot(data['Age'], hist=True, color='red')
plt.xlabel("Ages", fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.title("Density Plot of the Ages", fontsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# Text(0.5, 1.0, 'Density Plot of the Ages')

# %% [markdown]
# 전체적으로 20대 초반과 후반이 많이 분포해 있다는 것을 알 수 있다.
#
# 최고의 축구 무대에 비교적 나이 어린 선수들이 많다는 것이 놀랍다.

# %%
plt.figure(figsize=(15, 8))
sns.distplot(Tottenham['Age'], hist=True, color='red')
plt.xlabel("Ages", fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.title("Density Plot of the Ages", fontsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# Text(0.5, 1.0, 'Density Plot of the Ages')

# %% [markdown]
# 토트넘은 현재 EPL 추세와 비슷하게 젊은 선수들이 많다는 것을 알 수 있다.

# %% [markdown]
# ### 2. 문제점

# %%
goalsbyteam = data['Gls'].groupby(data['Team']).sum().sort_values(ascending=False).to_frame()
fig = px.bar(data_frame=goalsbyteam, x=goalsbyteam.index, y='Gls', color='Gls')
fig.update_layout(title_text='Number of Goals by the Teams',
                  title_x=0.5, title_font=dict(size=30))
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a8d6bcb1-84cf-4c71-a728-04f1d758a329" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8d6bcb1-84cf-4c71-a728-04f1d758a329")) {                    Plotly.newPlot(                        "a8d6bcb1-84cf-4c71-a728-04f1d758a329",                        [{"alignmentgroup":"True","hovertemplate":"Team=%{x}<br>Gls=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[96.0,94.0,75.0,63.0,62.0,60.0,58.0,56.0,50.0,50.0,46.0,42.0,42.0,41.0,41.0,40.0,35.0,33.0,32.0,21.0],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Manchester City","Liverpool","Chelsea","Tottenham Hotspur","Leicester City","Arsenal","West Ham United","Manchester United","Crystal Palace","Aston Villa","Brentford","Everton","Leeds United","Newcastle United","Southampton","Brighton & Hove Albion","Wolverhampton Wanderers","Watford","Burnley","Norwich City"],"xaxis":"x","y":[96.0,94.0,75.0,63.0,62.0,60.0,58.0,56.0,50.0,50.0,46.0,42.0,42.0,41.0,41.0,40.0,35.0,33.0,32.0,21.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %%
# 득점왕

fig_bar = px.bar(data_frame=data.nlargest(10, 'Gls')[['Player', 'Gls']],
x='Player', y='Gls', color='Gls', text='Gls')
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig_bar.update_layout(title_text='Top 10 Goal Kings of the League', 
title_x=0.5, title_font=dict(size=30)) 
fig_bar.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="000a0b71-a3ca-46d0-ab64-f4043d4f3656" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("000a0b71-a3ca-46d0-ab64-f4043d4f3656")) {                    Plotly.newPlot(                        "000a0b71-a3ca-46d0-ab64-f4043d4f3656",                        [{"alignmentgroup":"True","hovertemplate":"Player=%{x}<br>Gls=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[23.0,23.0,18.0,17.0,16.0,15.0,15.0,15.0,14.0,13.0],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[23.0,23.0,18.0,17.0,16.0,15.0,15.0,15.0,14.0,13.0],"textposition":"outside","x":["Mohamed Salah","Son Heung-min","Cristiano Ronaldo","Harry Kane","Sadio Man?","Jamie Vardy","Diogo Jota","Kevin De Bruyne","Wilfried Zaha","Raheem Sterling"],"xaxis":"x","y":[23.0,23.0,18.0,17.0,16.0,15.0,15.0,15.0,14.0,13.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
fig_bar = px.bar(data_frame=data.nlargest(10, 'Gls')[['Team', 'Gls']],
x='Team', y='Gls', color='Gls', text='Gls')
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig_bar.update_layout(title_text='The teams of top 10 Goal Kings of the League', 
title_x=0.5, title_font=dict(size=30)) 
fig_bar.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0429c890-0d98-4618-87fa-605a3f2540b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0429c890-0d98-4618-87fa-605a3f2540b4")) {                    Plotly.newPlot(                        "0429c890-0d98-4618-87fa-605a3f2540b4",                        [{"alignmentgroup":"True","hovertemplate":"Team=%{x}<br>Gls=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[23.0,23.0,18.0,17.0,16.0,15.0,15.0,15.0,14.0,13.0],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[23.0,23.0,18.0,17.0,16.0,15.0,15.0,15.0,14.0,13.0],"textposition":"outside","x":["Liverpool","Tottenham Hotspur","Manchester United","Tottenham Hotspur","Liverpool","Leicester City","Liverpool","Manchester City","Crystal Palace","Manchester City"],"xaxis":"x","y":[23.0,23.0,18.0,17.0,16.0,15.0,15.0,15.0,14.0,13.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26" ...

# %% [markdown]
# 팀 득점 1위였던, 맨체스터 시티(Manchester City)는 케빈 데 브라이너(Kevin De Bruyne)와 라힘 스털링(Raheem Sterling) 단 두명 만이 득점왕 10위에 랭크했다.
#
# 그들이 넣은 골 수는 28골 뿐이다. 나머지 68골은 다른 선수들이 득점했다는 것이다.
#
# 반면에, 토트넘은 두 선수가 40골을 넣었다. 나머지 선수들은 고작 23득점만 했을 뿐이다.
#
# 팀원들이 더 골을 넣어준다면, 다음 시즌은 더욱 높은 성적을 기록할 수 있을 거라 생각된다.

# %%
assistsbyteam = data['Ast'].groupby(data['Team']).sum().sort_values(ascending=False).to_frame()
fig = px.bar(data_frame=assistsbyteam, x=assistsbyteam.index, y='Ast', color='Ast')
fig.update_layout(title_text='Number of Assist by the Teams',
                  title_x=0.5, title_font=dict(size=30))
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="aadfa280-4e92-4c48-b5a1-2842d155a0af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aadfa280-4e92-4c48-b5a1-2842d155a0af")) {                    Plotly.newPlot(                        "aadfa280-4e92-4c48-b5a1-2842d155a0af",                        [{"alignmentgroup":"True","hovertemplate":"Team=%{x}<br>Ast=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[71.0,63.0,52.0,50.0,46.0,46.0,46.0,42.0,41.0,33.0,31.0,30.0,29.0,26.0,26.0,26.0,26.0,23.0,22.0,16.0],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Liverpool","Manchester City","Chelsea","Tottenham Hotspur","Leicester City","West Ham United","Manchester United","Aston Villa","Arsenal","Brentford","Crystal Palace","Brighton & Hove Albion","Everton","Leeds United","Burnley","Southampton","Watford","Newcastle United","Wolverhampton Wanderers","Norwich City"],"xaxis":"x","y":[71.0,63.0,52.0,50.0,46.0,46.0,46.0,42.0,41.0,33.0,31.0,30.0,29.0,26.0,26.0,26.0,26.0,23.0,22.0,16.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %%
# 도움왕

fig_bar = px.bar(data_frame=data.nlargest(10, 'Ast')[['Player', 'Ast']],
                 x='Player', y='Ast', color='Ast', text='Ast')
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig_bar.update_layout(title_text='Top 10 Assists Kings of the League', 
                      title_x=0.5, title_font=dict(size=30)) 
fig_bar.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f45f19b0-f8bd-4dfe-9a0e-bfd409c8a505" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f45f19b0-f8bd-4dfe-9a0e-bfd409c8a505")) {                    Plotly.newPlot(                        "f45f19b0-f8bd-4dfe-9a0e-bfd409c8a505",                        [{"alignmentgroup":"True","hovertemplate":"Player=%{x}<br>Ast=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[13.0,12.0,10.0,10.0,10.0,10.0,9.0,9.0,9.0,8.0],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[13.0,12.0,10.0,10.0,10.0,10.0,9.0,9.0,9.0,8.0],"textposition":"outside","x":["Mohamed Salah","Trent Alexander-Arnold","Mason Mount","Harvey Barnes","Andrew Robertson","Jarrod Bowen","Reece James","Paul Pogba","Harry Kane","James Maddison"],"xaxis":"x","y":[13.0,12.0,10.0,10.0,10.0,10.0,9.0,9.0,9.0,8.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f92 ...

# %%
fig_bar = px.bar(data_frame=data.nlargest(10, 'Ast')[['Team', 'Ast']],
x='Team', y='Ast', color='Ast', text='Ast')
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig_bar.update_layout(title_text='The team of top 10 Assists Kings of the League', 
title_x=0.5, title_font=dict(size=30)) 
fig_bar.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="90b1be3a-a4a3-4c3d-898a-588fce57d5a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90b1be3a-a4a3-4c3d-898a-588fce57d5a0")) {                    Plotly.newPlot(                        "90b1be3a-a4a3-4c3d-898a-588fce57d5a0",                        [{"alignmentgroup":"True","hovertemplate":"Team=%{x}<br>Ast=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[13.0,12.0,10.0,10.0,10.0,10.0,9.0,9.0,9.0,8.0],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[13.0,12.0,10.0,10.0,10.0,10.0,9.0,9.0,9.0,8.0],"textposition":"outside","x":["Liverpool","Liverpool","Chelsea","Leicester City","Liverpool","West Ham United","Chelsea","Manchester United","Tottenham Hotspur","Leicester City"],"xaxis":"x","y":[13.0,12.0,10.0,10.0,10.0,10.0,9.0,9.0,9.0,8.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"his ...

# %% [markdown]
# 어시스트 1위 팀인 리버풀(Liverpool) 선수인 모하메드 살라(Mohamed Salah), 트렌트 알렉산더 아놀드(Trent Alexander-Arnold)와 앤드류 로버트슨(Andrew Robertson)이 도움왕 1등, 2등, 3등을 나란히 헀다. 그들의 팀은 최종 순위에 2등을 했다.
#
# 도움을 많이 하는 것은 팀 순위에 영향을 끼친다라고 결론을 내릴 수 있다.
#
# 하지만 토트넘 선수는 한명만 이름을 올리고 있다. 도움을 올려줄 선수가 필요하다.

# %% [markdown]
# 그렇다면, 토트넘은 올해 이적 시장을 잘 보내고 있는가 ?

# %% [markdown]
# ### 3. 보완점 (이적생)

# %% [markdown]
# 다른 리그에서 이적해 온 선수들은 데이터에 없어 비교를 하지 못한다.
#
# 그래서 자국 내에서 이적한 선수들만 비교할 것이다.
#
# ps) 미드필드 지표도 데이터에 없어서, 필요한 선수들만 데이터를 추가했다.

# %%
# 레이다 그래프 만들기

def Playwell(trace1):
    x = data[data["Player"] == trace1]
    trace1 = go.Scatterpolar(
      r = [x['Ast'].values[0], x["xA"].values[0], x['Gls'].values[0], x['xG'].values[0], x['G-PK'].values[0], x['MP'].values[0]],
      theta = ['Assists', "Expected Assists", 'Goals','Expected Goals','Filed_Goals','Matches played'],
      fill = 'toself',
      name = trace1
    )
    return trace1

def PlayerSpotlight(trace1):
    trace1 = Playwell(trace1)
    layout = go.Layout(
          xaxis=dict(
            domain=[0, 0.45]
            ),
            yaxis=dict(
            domain=[0, 0.45]
            ),
        
           
          showlegend = True,
          title = "Player Performance"
    )

    data = [trace1]
    fig = go.Figure(data=data, layout=layout)

    fig.show()

# 선수들 관의 데이터 비교 레이더 그래프

def PlayerFight(trace1,trace2,trace3,trace4):
  trace1 = Playwell(trace1) 
  trace2 = Playwell(trace2)
  trace3 = Playwell(trace3)
  trace4 = Playwell(trace4)
  layout = go.Layout(
    xaxis=dict(
          domain=[0, 0.50]
      ),
      yaxis=dict(
           domain=[0, 0.50]
      ),
      xaxis2=dict(
          domain=[0.70, 1]
      ),
       xaxis3=dict(
          domain=[0, 0.50],
          anchor='y3'
      ),
      xaxis4=dict(
          domain=[0.70, 1],
           anchor='y4'
      ),
       yaxis2=dict(
          domain=[0, 0.50],
          anchor='x2'
      ),
       yaxis3=dict(
          domain=[0.70, 1]
      ),
      yaxis4=dict(
          domain=[0.70, 1],
          anchor='x4'
      ),
    showlegend = True,
     title = "Player Fight (who will you bet on!)"
  )

  data = [trace1, trace2, trace3, trace4]
  fig = go.Figure(data=data, layout=layout)

  fig.show()

# %% [markdown]
# 어시스트(Ast), 어시스트 기댓값(xA), 골 수(Gls), 골 넣을 기댓값(xG), 필드골(G-PK), 경기에 뛴 시간(Mp)를 기준으로 비교하겠다.

# %% [markdown]
# 공격수를 평가하는데, 왜 MP를 넣는 지 의아하다고 생각하는 사람이 있을 수도 있다.
#
# 토트넘은 옛날부터, 부상 병동이라고 불릴 만큼 부상자가 많았다. 그래서, MP 시간이 보장이 중요하다

# %% [markdown]
# #### 1. 공격수 비교

# %% [markdown]
# 이번 여름 시장에서 에버튼 공격수인 히샬리송(Richarlison) 을 영입했다.
#
# 공격 포인트가 절실한 토트넘에 도움을 줄 수 있는 지 확인해보자.
#
# 다음은 득점왕 경쟁을 하던 5위 선수들과 영입생을 비교한 그래프다,

# %%
# 득점왕 5등들과 영입생 비교

PlayerFight("Richarlison", 'Diogo Jota', 'Jamie Vardy', 'Wilfried Zaha')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a0b5ac53-fb76-4d16-a0dd-6cc7035f5447" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0b5ac53-fb76-4d16-a0dd-6cc7035f5447")) {                    Plotly.newPlot(                        "a0b5ac53-fb76-4d16-a0dd-6cc7035f5447",                        [{"fill":"toself","name":"Richarlison","r":[5.0,2.4,10.0,10.2,7.0,30],"theta":["Assists","Expected Assists","Goals","Expected Goals","Filed_Goals","Matches played"],"type":"scatterpolar"},{"fill":"toself","name":"Diogo Jota","r":[4.0,5.5,15.0,16.1,15.0,35],"theta":["Assists","Expected Assists","Goals","Expected Goals","Filed_Goals","Matches played"],"type":"scatterpolar"},{"fill":"toself","name":"Jamie Vardy","r":[2.0,1.6,15.0,9.5,15.0,25],"theta":["Assists","Expected Assists","Goals","Expected Goals","Filed_Goals","Matches played"],"type":"scatterpolar"},{"fill":"toself","name":"Wilfried Zaha","r":[1.0,4.8,14.0,9.4,9.0,33],"theta":["Assists","Expected Assists","Goals","Expected Goals","Filed_Goals","Matches played"],"type":"scatterpolar"}],                        {"showlegend":true,"title":{"text":"Player Fight (who will you bet on!)"},"xaxis":{"domain":[0,0.5]},"yaxis":{"domain":[0,0.5]},"xaxis2":{"domain":[0.7,1]},"xaxis3":{"anchor":"y3","domain":[0,0.5]},"xaxis4":{"anchor":"y4","domain":[0.7,1]},"yaxis2":{"anchor":"x2","domain":[0,0.5]},"yaxis3":{"domain":[0.7,1]},"yaxis4":{"anchor":"x4","domain":[0.7,1]},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888888 ...

# %% [markdown]
# 디오구 조타(Diogo Jota)를 제외한 득점왕을 경쟁했던 공격수들과 비교했을 때, 밀리지 않는 수치를 보여준다.

# %% [markdown]
# 따라서, 히샬리송(Richarlison)은 아주 좋은 영입이라고 볼 수 있다.

# %% [markdown]
# #### 2. 미드필더 비교

# %% [markdown]
# 이번 여름 시장에서 브라이턴에서 수비형 미드필더인 이브 비수마(Yves Bissouma)를 영입했다.
#
# 그가 토트넘에서 무엇을 보완해줄 수 있을 지 확인해보자.
#
# 수비형 미드필더는 수비 능력과 공을 운반하는 능력이 중요하다,
#
# 그래서 드리블 성공률(SuccDrib),
# 수비 능력인 공 가로채기(Interception), 압박 성공률(%SuccPress), 공을 운반하는 능력인 드리블 성공률(SuccDrib)을 데이터에 추가했다.

# %%
Tottenham = data[(data['Team'] == 'Tottenham Hotspur') | (data['Player'] == 'Yves Bissouma')]

# %%
# 토트넘 미드필더만 남기기

Tottenham_mid = Tottenham.dropna(subset=['SuccDrib'])

# %%
# 드리브 성공률 계산

Tottenham_mid['%Drib'] = Tottenham_mid['SuccDrib']/Tottenham_mid['AtmpDrib']

# %%
# 미드필더 능력 지표

def Playwell(trace1):
    x = data[data["Player"] == trace1]
    trace1 = go.Scatterpolar(
      r = [x['Ast'].values[0], x["xA"].values[0], x['%SuccPress'].values[0], x['Interception'].values[0], x['Clearances'].values[0]],
      theta = ['Assists', "Expected Assists", '%SuccPress','Interception', 'Clearances'],
      fill = 'toself',
      name = trace1
    )
    return trace1

# %%
# 드리블 비교

fig_bar = px.bar(data_frame=Tottenham_mid.nlargest(5, '%Drib')[['Player', '%Drib']],
                 x='Player', y='%Drib', color='%Drib', text='%Drib')
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=2)))
fig_bar.update_layout(title_text='Tottenham\'s Midfielder Dribble',  # Main title for the project
                      title_x=0.5, title_font=dict(size=30))  # Location and the font size of the main title
fig_bar.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1738a81c-d39f-4a2e-88ae-e74c698b1ff6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1738a81c-d39f-4a2e-88ae-e74c698b1ff6")) {                    Plotly.newPlot(                        "1738a81c-d39f-4a2e-88ae-e74c698b1ff6",                        [{"alignmentgroup":"True","hovertemplate":"Player=%{x}<br>%Drib=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.8,0.6666666666666666,0.5882352941176471,0.5416666666666666,0.5],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"#000000","width":2}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.8,0.6666666666666666,0.5882352941176471,0.5416666666666666,0.5],"textposition":"outside","x":["Yves Bissouma","Oliver Skipp","Pierre H?bjerg","Tanguy Ndombele","Harry Winks"],"xaxis":"x","y":[0.8,0.6666666666666666,0.5882352941176471,0.5416666666666666,0.5],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2 ...

# %%
# 토트넘 미드필더와 영입생 비교

PlayerFight("Yves Bissouma", 'Pierre H?bjerg', 'Oliver Skipp', 'Harry Winks')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="93ed9e3f-2b34-4a85-9b5e-0b80466ab1fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93ed9e3f-2b34-4a85-9b5e-0b80466ab1fc")) {                    Plotly.newPlot(                        "93ed9e3f-2b34-4a85-9b5e-0b80466ab1fc",                        [{"fill":"toself","name":"Yves Bissouma","r":[2.0,0.8,35.1,29.0,24.0],"theta":["Assists","Expected Assists","%SuccPress","Interception","Clearances"],"type":"scatterpolar"},{"fill":"toself","name":"Pierre H?bjerg","r":[2.0,2.5,30.4,37.0,22.0],"theta":["Assists","Expected Assists","%SuccPress","Interception","Clearances"],"type":"scatterpolar"},{"fill":"toself","name":"Oliver Skipp","r":[0.0,0.9,25.2,19.0,12.0],"theta":["Assists","Expected Assists","%SuccPress","Interception","Clearances"],"type":"scatterpolar"},{"fill":"toself","name":"Harry Winks","r":[1.0,1.5,26.8,15.0,3.0],"theta":["Assists","Expected Assists","%SuccPress","Interception","Clearances"],"type":"scatterpolar"}],                        {"showlegend":true,"title":{"text":"Player Fight (who will you bet on!)"},"xaxis":{"domain":[0,0.5]},"yaxis":{"domain":[0,0.5]},"xaxis2":{"domain":[0.7,1]},"xaxis3":{"anchor":"y3","domain":[0,0.5]},"xaxis4":{"anchor":"y4","domain":[0.7,1]},"yaxis2":{"anchor":"x2","domain":[0,0.5]},"yaxis3":{"domain":[0.7,1]},"yaxis4":{"anchor":"x4","domain":[0.7,1]},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram ...

# %% [markdown]
# 비수마는 Interception 제외하고는 토트넘 미드필더 에이스인 호이비에르(Pierre H?bjerg) 보다  모든 수치에서 높은 것을 볼 수 있다.
#
# 이로써, 비수마는 좋은 영입이라고 판단된다.

# %% [markdown]
# 두 선수를 봤을 때, 현재까지는 이적 시장을 잘 보내고 있다고 평가할만 하다.
#
# 하지만,
# 앞서 어시스트 중요성을 말한 만큼, 좋은 패스를 해줄 수 있는 미드필더도 속히 영입되기를 바란다.

# %% [markdown]
# # 2. 실제와 게임과의 상관관계

# %% [markdown]
# 아쉽게도 데이터 셋이 공격 포인트 위주로만 있다. 따라서, 득점 랭킹 20위까지만을 가지고 게임 데이터로 비교해 보겠다.

# %% [markdown]
# 피파온라인4 게임 데이터인 골 결정력(G-AC), 스테미너(Sta), 패널트킥(PKG)를 column에 추가했다.

# %%
# 20위까지 추출

data.sort_values(by='Gls', ascending=False).head(20)
# Out:
#                    Player               Team   Nation    Pos   Age  MP  \
# 356         Mohamed Salah          Liverpool   eg EGY     FW  29.0  35
# 556         Son Heung-min  Tottenham Hotspur   kr KOR  FW,MF  29.0  35
# 423     Cristiano Ronaldo  Manchester United   pt POR     FW  36.0  30
# 553            Harry Kane  Tottenham Hotspur  eng ENG     FW  28.0  37
# 354            Sadio Man?          Liverpool   sn SEN     FW  29.0  34
# 392       Kevin De Bruyne    Manchester City   be BEL     MF  30.0  30
# 359            Diogo Jota          Liverpool   pt POR     FW  24.0  35
# 328           Jamie Vardy     Leicester City  eng ENG     FW  34.0  25
# 220         Wilfried Zaha     Crystal Palace   ci CIV     FW  28.0  33
# 394       Raheem Sterling    Manchester City  eng ENG     FW  26.0  30
# 86             Ivan Toney          Brentford  eng ENG     FW  25.0  33
# 629          Jarrod Bowen    West Ham United  eng ENG     FW  24.0  36
# 322        James Maddison     Leicester City  eng ENG  MF,FW  24.0  35
# 399          Riyad Mahrez    Manchester City   dz ALG     FW  30.0  28
# 288  Raphael Dias Belloli       Leeds United   br BRA  FW,MF  24.0  35
# 45          Ollie Watkins        Aston Villa  eng ENG     FW  25.0  35
# 188           Mason Mount            Chelsea  eng ENG  MF,FW  22.0  32
# 0             Bukayo Saka            Arsenal  eng ENG  FW,MF  19.0  38
# 488           Teemu Pukki       Norwich City   fi FIN     FW  31.0  37
# 420       Bruno Fernandes  Manchester United   pt POR     MF  26.0  36
#
#      Starts    Min   90s   Gls  ...  npxG.1  npxG+xA.1  %SuccPress  SuccDrib  \
# 356      30  2,762  30.7  23.0  ...    0.55       0.89         NaN       NaN
# 556      35  3,006  33.4  23.0  ...    0.49       0.73         NaN       NaN
# 423      27  2,456  27.3  18.0  ...    0.52       0.64         NaN       NaN
# 553      36  3,232  35.9  17.0  ...    0.48       0.73         NaN       NaN
# 354      32  2,819  31.3  16.0  ...    0.53       0.67         NaN       NaN
# 392      25  2,201  24.5  15.0  ...    0.26       0.65         NaN       NaN
# 359      27  2,364  26.3  15.0  ...    0.61       0.82         NaN       NaN
# 328      20  1,806  20.1  15.0  ...    0.47       0.55         NaN       NaN
# 220      31  2,760  30.7  14.0  ...    0.13       0.29         NaN       NaN
# 394      23  2,128  23.6  13.0  ...    0.51       0.70         NaN       NaN
# 86       32  2,909  32.3  12.0  ...    0.25       0.43         NaN       NaN
# 629      34  2,983  33.1  12.0  ...    0.34       0.51         NaN       NaN
# 322      28  2,459  27.3  12.0  ...    0.30       0.48         NaN       NaN
# 399      15  1,498  16.6  11.0  ...    0.38       0.60         NaN       NaN
# 288      34  2,915  32.4  11.0  ...    0.25       0.46         NaN       NaN
# 45       33  2,952  32.8  11.0  ...    0.35       0.44         NaN       NaN
# 188      27  2,363  26.3  11.0  ...    0.31       0.56         NaN       NaN
# 0        36  2,978  33.1  11.0  ...    0.25       0.46         NaN       NaN
# 488      37  3,253  36.1  11.0  ...    0.26       0.33         NaN       NaN
# 420      35  3,111  34.6  10.0  ...    0.24       0.48         NaN       NaN
#
#      AtmpDrib  Interception  Clearances  G-AC   Sta   PKG
# 356       NaN           NaN         NaN  85.0  80.0  79.0
# 556       NaN           NaN         NaN  86.0  86.0  72.0
# 423       NaN           NaN         NaN  86.0  71.0  83.0
# 553       NaN           NaN         NaN  91.0  80.0  89.0
# 354       NaN           NaN         NaN  80.0  79.0  70.0
# 392       NaN           NaN         NaN  78.0  84.0  79.0
# 359       NaN           NaN         NaN  79.0  77.0  64.0
# 328       NaN           NaN         NaN  85.0  73.0  81.0
# 220       NaN           NaN         NaN  73.0  71.0  71.0
# 394       NaN           NaN         NaN  77.0  75.0  67.0
# 86        NaN           NaN         NaN  75.0  74.0  77.0
# 629       NaN           NaN         NaN  78.0  77.0  68.0
# 322       NaN           NaN         NaN  75.0  74.0  74.0
# 399       NaN           NaN         NaN  77.0  69.0  74.0
# 288       NaN           NaN         NaN  70.0  78.0  67.0
# 45        NaN           NaN         NaN  77.0  84.0  62.0
# 188       NaN           NaN         NaN  75.0  81.0  63.0
# 0         NaN           NaN         NaN  71.0  76.0  61.0
# 488       NaN           NaN         NaN  73.0  71.0  67.0
# 420       NaN           NaN         NaN  75.0  82.0  82.0
#
# [20 rows x 38 columns]

# %%
score_20 = data[ data['Gls'] >= 11]
score_20_origin = data[ data['Gls'] >= 11]

# %%
score_20
# Out:
#                    Player               Team   Nation    Pos   Age  MP  \
# 0             Bukayo Saka            Arsenal  eng ENG  FW,MF  19.0  38
# 45          Ollie Watkins        Aston Villa  eng ENG     FW  25.0  35
# 86             Ivan Toney          Brentford  eng ENG     FW  25.0  33
# 188           Mason Mount            Chelsea  eng ENG  MF,FW  22.0  32
# 220         Wilfried Zaha     Crystal Palace   ci CIV     FW  28.0  33
# 288  Raphael Dias Belloli       Leeds United   br BRA  FW,MF  24.0  35
# 322        James Maddison     Leicester City  eng ENG  MF,FW  24.0  35
# 328           Jamie Vardy     Leicester City  eng ENG     FW  34.0  25
# 354            Sadio Man?          Liverpool   sn SEN     FW  29.0  34
# 356         Mohamed Salah          Liverpool   eg EGY     FW  29.0  35
# 359            Diogo Jota          Liverpool   pt POR     FW  24.0  35
# 392       Kevin De Bruyne    Manchester City   be BEL     MF  30.0  30
# 394       Raheem Sterling    Manchester City  eng ENG     FW  26.0  30
# 399          Riyad Mahrez    Manchester City   dz ALG     FW  30.0  28
# 423     Cristiano Ronaldo  Manchester United   pt POR     FW  36.0  30
# 488           Teemu Pukki       Norwich City   fi FIN     FW  31.0  37
# 553            Harry Kane  Tottenham Hotspur  eng ENG     FW  28.0  37
# 556         Son Heung-min  Tottenham Hotspur   kr KOR  FW,MF  29.0  35
# 629          Jarrod Bowen    West Ham United  eng ENG     FW  24.0  36
#
#      Starts    Min   90s   Gls  ...  npxG.1  npxG+xA.1  %SuccPress  SuccDrib  \
# 0        36  2,978  33.1  11.0  ...    0.25       0.46         NaN       NaN
# 45       33  2,952  32.8  11.0  ...    0.35       0.44         NaN       NaN
# 86       32  2,909  32.3  12.0  ...    0.25       0.43         NaN       NaN
# 188      27  2,363  26.3  11.0  ...    0.31       0.56         NaN       NaN
# 220      31  2,760  30.7  14.0  ...    0.13       0.29         NaN       NaN
# 288      34  2,915  32.4  11.0  ...    0.25       0.46         NaN       NaN
# 322      28  2,459  27.3  12.0  ...    0.30       0.48         NaN       NaN
# 328      20  1,806  20.1  15.0  ...    0.47       0.55         NaN       NaN
# 354      32  2,819  31.3  16.0  ...    0.53       0.67         NaN       NaN
# 356      30  2,762  30.7  23.0  ...    0.55       0.89         NaN       NaN
# 359      27  2,364  26.3  15.0  ...    0.61       0.82         NaN       NaN
# 392      25  2,201  24.5  15.0  ...    0.26       0.65         NaN       NaN
# 394      23  2,128  23.6  13.0  ...    0.51       0.70         NaN       NaN
# 399      15  1,498  16.6  11.0  ...    0.38       0.60         NaN       NaN
# 423      27  2,456  27.3  18.0  ...    0.52       0.64         NaN       NaN
# 488      37  3,253  36.1  11.0  ...    0.26       0.33         NaN       NaN
# 553      36  3,232  35.9  17.0  ...    0.48       0.73         NaN       NaN
# 556      35  3,006  33.4  23.0  ...    0.49       0.73         NaN       NaN
# 629      34  2,983  33.1  12.0  ...    0.34       0.51         NaN       NaN
#
#      AtmpDrib  Interception  Clearances  G-AC   Sta   PKG
# 0         NaN           NaN         NaN  71.0  76.0  61.0
# 45        NaN           NaN         NaN  77.0  84.0  62.0
# 86        NaN           NaN         NaN  75.0  74.0  77.0
# 188       NaN           NaN         NaN  75.0  81.0  63.0
# 220       NaN           NaN         NaN  73.0  71.0  71.0
# 288       NaN           NaN         NaN  70.0  78.0  67.0
# 322       NaN           NaN         NaN  75.0  74.0  74.0
# 328       NaN           NaN         NaN  85.0  73.0  81.0
# 354       NaN           NaN         NaN  80.0  79.0  70.0
# 356       NaN           NaN         NaN  85.0  80.0  79.0
# 359       NaN           NaN         NaN  79.0  77.0  64.0
# 392       NaN           NaN         NaN  78.0  84.0  79.0
# 394       NaN           NaN         NaN  77.0  75.0  67.0
# 399       NaN           NaN         NaN  77.0  69.0  74.0
# 423       NaN           NaN         NaN  86.0  71.0  83.0
# 488       NaN           NaN         NaN  73.0  71.0  67.0
# 553       NaN           NaN         NaN  91.0  80.0  89.0
# 556       NaN           NaN         NaN  86.0  86.0  72.0
# 629       NaN           NaN         NaN  78.0  77.0  68.0
#
# [19 rows x 38 columns]

# %%
# pk 정확성을 위한 계산

score_20['%pk']= score_20['PK'] / score_20['PKatt']

# %% [markdown]
# 왜 ? 많은 패널트킥 기회를 얻은 사람이 패널트킥 득점을 많이 했을 확률이 높다.
#
# 보다 정확하게, 패널트킥 능력을 보려고 한다면, 패널트킥 성공률을 보는 것이 정확하다.
#
# 하지만, 패널트킥을 단 한 번도, 차지 않는 선수들이 있다. 이 선수들의 널값을 0으로 처리해주겠다.

# %%
# 널 값을 0으로 바꿔서 값을 쓸 수 있게 만든다

score_20['%pk'] = score_20['%pk'].fillna(value=0)

# %%
score_20
# Out:
#                    Player               Team   Nation    Pos   Age  MP  \
# 0             Bukayo Saka            Arsenal  eng ENG  FW,MF  19.0  38
# 45          Ollie Watkins        Aston Villa  eng ENG     FW  25.0  35
# 86             Ivan Toney          Brentford  eng ENG     FW  25.0  33
# 188           Mason Mount            Chelsea  eng ENG  MF,FW  22.0  32
# 220         Wilfried Zaha     Crystal Palace   ci CIV     FW  28.0  33
# 288  Raphael Dias Belloli       Leeds United   br BRA  FW,MF  24.0  35
# 322        James Maddison     Leicester City  eng ENG  MF,FW  24.0  35
# 328           Jamie Vardy     Leicester City  eng ENG     FW  34.0  25
# 354            Sadio Man?          Liverpool   sn SEN     FW  29.0  34
# 356         Mohamed Salah          Liverpool   eg EGY     FW  29.0  35
# 359            Diogo Jota          Liverpool   pt POR     FW  24.0  35
# 392       Kevin De Bruyne    Manchester City   be BEL     MF  30.0  30
# 394       Raheem Sterling    Manchester City  eng ENG     FW  26.0  30
# 399          Riyad Mahrez    Manchester City   dz ALG     FW  30.0  28
# 423     Cristiano Ronaldo  Manchester United   pt POR     FW  36.0  30
# 488           Teemu Pukki       Norwich City   fi FIN     FW  31.0  37
# 553            Harry Kane  Tottenham Hotspur  eng ENG     FW  28.0  37
# 556         Son Heung-min  Tottenham Hotspur   kr KOR  FW,MF  29.0  35
# 629          Jarrod Bowen    West Ham United  eng ENG     FW  24.0  36
#
#      Starts    Min   90s   Gls  ...  npxG+xA.1  %SuccPress  SuccDrib  \
# 0        36  2,978  33.1  11.0  ...       0.46         NaN       NaN
# 45       33  2,952  32.8  11.0  ...       0.44         NaN       NaN
# 86       32  2,909  32.3  12.0  ...       0.43         NaN       NaN
# 188      27  2,363  26.3  11.0  ...       0.56         NaN       NaN
# 220      31  2,760  30.7  14.0  ...       0.29         NaN       NaN
# 288      34  2,915  32.4  11.0  ...       0.46         NaN       NaN
# 322      28  2,459  27.3  12.0  ...       0.48         NaN       NaN
# 328      20  1,806  20.1  15.0  ...       0.55         NaN       NaN
# 354      32  2,819  31.3  16.0  ...       0.67         NaN       NaN
# 356      30  2,762  30.7  23.0  ...       0.89         NaN       NaN
# 359      27  2,364  26.3  15.0  ...       0.82         NaN       NaN
# 392      25  2,201  24.5  15.0  ...       0.65         NaN       NaN
# 394      23  2,128  23.6  13.0  ...       0.70         NaN       NaN
# 399      15  1,498  16.6  11.0  ...       0.60         NaN       NaN
# 423      27  2,456  27.3  18.0  ...       0.64         NaN       NaN
# 488      37  3,253  36.1  11.0  ...       0.33         NaN       NaN
# 553      36  3,232  35.9  17.0  ...       0.73         NaN       NaN
# 556      35  3,006  33.4  23.0  ...       0.73         NaN       NaN
# 629      34  2,983  33.1  12.0  ...       0.51         NaN       NaN
#
#      AtmpDrib  Interception  Clearances  G-AC   Sta   PKG       %pk
# 0         NaN           NaN         NaN  71.0  76.0  61.0  1.000000
# 45        NaN           NaN         NaN  77.0  84.0  62.0  1.000000
# 86        NaN           NaN         NaN  75.0  74.0  77.0  1.000000
# 188       NaN           NaN         NaN  75.0  81.0  63.0  1.000000
# 220       NaN           NaN         NaN  73.0  71.0  71.0  0.714286
# 288       NaN           NaN         NaN  70.0  78.0  67.0  1.000000
# 322       NaN           NaN         NaN  75.0  74.0  74.0  0.000000
# 328       NaN           NaN         NaN  85.0  73.0  81.0  0.000000
# 354       NaN           NaN         NaN  80.0  79.0  70.0  0.000000
# 356       NaN           NaN         NaN  85.0  80.0  79.0  0.833333
# 359       NaN           NaN         NaN  79.0  77.0  64.0  0.000000
# 392       NaN           NaN         NaN  78.0  84.0  79.0  0.000000
# 394       NaN           NaN         NaN  77.0  75.0  67.0  0.666667
# 399       NaN           NaN         NaN  77.0  69.0  74.0  0.800000
# 423       NaN           NaN         NaN  86.0  71.0  83.0  1.000000
# 488       NaN           NaN         NaN  73.0  71.0  67.0  1.000000
# 553       NaN           NaN         NaN  91.0  80.0  89.0  1.000000
# 556       NaN           NaN         NaN  86.0  86.0  72.0  0.000000
# 629       NaN           NaN         NaN  78.0  77.0  68.0  0.000000
#
# [19 rows x 39 columns]

# %% [markdown]
# 과연, 실제와 게임상의 상관관계가 있을까?

# %% [markdown]
# G-PK : 패널트킥을 제외한 필드 골
#
# 90s : 전체 출전 시간을 90분으로 나눈 값
#
# %pk : 패널트킥을 넣을 확률
#
# G-AC : 게임 속 골 결정력
#
# Sta : 게임 속 스테미너(체력)
#
# PKG : 게임 속 패널트킥 능력

# %%
corrMat = score_20[['90s', 'G-PK', 'G-AC', 'Sta', 'PKG', '%pk']].corr() 
fig, ax = plt.subplots()
fig.set_size_inches(12, 12)
sns.heatmap(corrMat, annot=True)    # 상관관계 히트맵 그리기
ax.set(title='Heatmap of Numerical Data');

# %% [markdown]
# G-PK와 G-AC와 연관이 있어 보인다. -> 0.73
#
# 90s와 스테미너가 연관 있다. -> 0.33
#
# %pk는 안 찬 사람이 있어, PKG와 음의 관계가 띈다고 판단된다. - > -0.056
#
# 결론, 약간 씩의 상관관계가 있어 보이지만, 영향력이 거의 없다고 판단된다.

# %% [markdown]
# # 3. 게임 능력치 만들어 보기

# %% [markdown]
# G-PK를 게임상의 골 결정력으로, 90s를 게임상의 스테미너로, Pk를 게임상의 패널트킥 능력으로 계산하여 만들어 보겠다.

# %% [markdown]
# 우선 실제로 pk를 안 찬 사람들을 게임상 패널트킥 평균 값으로 대체하겠다.

# %%
score_20 = score_20[['Player','G-PK', 'G-AC','90s','Sta','%pk','PKG']]
score_20_orgin = score_20_origin[['Player','G-AC','Sta','PKG']]

# %%
# pk 안찬 사람들의 게임상의 패널트킥 능력 값

score_20[score_20["%pk"] ==0].describe()
# Out:
#             G-PK       G-AC       90s        Sta  %pk        PKG
# count   7.000000   7.000000   7.00000   7.000000  7.0   7.000000
# mean   15.428571  80.142857  28.00000  78.571429  0.0  72.571429
# std     3.690399   3.976119   4.90068   4.859943  0.0   5.996030
# min    12.000000  75.000000  20.10000  73.000000  0.0  64.000000
# 25%    13.500000  78.000000  25.40000  75.500000  0.0  69.000000
# 50%    15.000000  79.000000  27.30000  77.000000  0.0  72.000000
# 75%    15.500000  82.500000  32.20000  81.500000  0.0  76.500000
# max    23.000000  86.000000  33.40000  86.000000  0.0  81.000000

# %%
# 패널트킥 능력 72로 주기

score_20.loc[score_20['%pk']==0,'PKG']=72

# %%
# 실제 능력과 게임 지표 평균과 분포 나타내보기

score_20.describe()
# Out:
#             G-PK       G-AC        90s        Sta        %pk        PKG
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean   12.210526  78.473684  29.147368  76.842105   0.579699  71.789474
# std     4.263266   5.719056   5.277243   4.879244   0.465720   6.932844
# min     7.000000  70.000000  16.600000  69.000000   0.000000  61.000000
# 25%     9.000000  75.000000  26.300000  73.500000   0.000000  67.000000
# 50%    12.000000  77.000000  30.700000  77.000000   0.800000  72.000000
# 75%    15.000000  82.500000  32.950000  80.000000   1.000000  73.000000
# max    23.000000  91.000000  36.100000  86.000000   1.000000  89.000000

# %%
# 패널트킥 능력치 배분

score_20.loc[score_20['%pk']<=0.5,'PKG']=80
score_20.loc[(score_20['%pk']> 0.5) & (score_20['%pk'] <= 0.7 ),'PKG']=83
score_20.loc[(score_20['%pk']> 0.7) & (score_20['%pk'] <= 0.8 ),'PKG']=85
score_20.loc[score_20['%pk']==1.0,'PKG']=89

# %% [markdown]
# 패널트킥 한 번도 안 찬 사람들에게 72 능력치를 주었다. 비교적, 패널트킥을 한 번이라도 성공시킨 사람들은 이들 보다 큰 차이가 있어야 된다고 생각했다.
#
# 따라서, 제일 낮은 수를 +8로 능력을 줬다.

# %%
# 골 결정력 배분

score_20.loc[score_20['G-PK']==7,'G-AC']=70
score_20.loc[(score_20['G-PK']> 7) & (score_20['G-PK'] <= 9 ),'G-AC']=75
score_20.loc[(score_20['G-PK']> 9) & (score_20['G-PK'] <= 11 ),'G-AC']=77
score_20.loc[(score_20['G-PK']> 11) & (score_20['G-PK'] <= 12 ),'G-AC']=80
score_20.loc[(score_20['G-PK']> 12) & (score_20['G-PK'] <= 15 ),'G-AC']=82
score_20.loc[(score_20['G-PK']> 15) & (score_20['G-PK'] <= 20 ),'G-AC']=84
score_20.loc[(score_20['G-PK']> 20) & (score_20['G-PK'] <= 21 ),'G-AC']=86
score_20.loc[(score_20['G-PK']> 21) & (score_20['G-PK'] <= 22 ),'G-AC']=88
score_20.loc[score_20['G-PK']>=23,'G-AC']=90

# %%
# 스테미너 배분

score_20.loc[score_20['90s']<20.1,'Sta']=66
score_20.loc[score_20['90s']==20.1,'Sta']=68
score_20.loc[(score_20['90s']> 20.1) & (score_20['90s'] <= 25 ),'Sta']=75
score_20.loc[(score_20['90s']> 25) & (score_20['90s'] <= 27 ),'Sta']=81
score_20.loc[(score_20['90s']> 27.) & (score_20['90s'] <= 33 ),'Sta']=82
score_20.loc[(score_20['90s']> 33) & (score_20['90s'] <= 36 ),'Sta']=83
score_20.loc[score_20['90s']>36,'Sta']=86
score_20
# Out:
#                    Player  G-PK  G-AC   90s   Sta       %pk   PKG
# 0             Bukayo Saka   9.0  75.0  33.1  83.0  1.000000  89.0
# 45          Ollie Watkins  10.0  77.0  32.8  82.0  1.000000  89.0
# 86             Ivan Toney   7.0  70.0  32.3  82.0  1.000000  89.0
# 188           Mason Mount  10.0  77.0  26.3  81.0  1.000000  89.0
# 220         Wilfried Zaha   9.0  75.0  30.7  82.0  0.714286  85.0
# 288  Raphael Dias Belloli   7.0  70.0  32.4  82.0  1.000000  89.0
# 322        James Maddison  12.0  80.0  27.3  82.0  0.000000  80.0
# 328           Jamie Vardy  15.0  82.0  20.1  68.0  0.000000  80.0
# 354            Sadio Man?  16.0  84.0  31.3  82.0  0.000000  80.0
# 356         Mohamed Salah  18.0  84.0  30.7  82.0  0.833333  79.0
# 359            Diogo Jota  15.0  82.0  26.3  81.0  0.000000  80.0
# 392       Kevin De Bruyne  15.0  82.0  24.5  75.0  0.000000  80.0
# 394       Raheem Sterling  11.0  77.0  23.6  75.0  0.666667  83.0
# 399          Riyad Mahrez   7.0  70.0  16.6  66.0  0.800000  85.0
# 423     Cristiano Ronaldo  15.0  82.0  27.3  82.0  1.000000  89.0
# 488           Teemu Pukki   8.0  75.0  36.1  86.0  1.000000  89.0
# 553            Harry Kane  13.0  82.0  35.9  83.0  1.000000  89.0
# 556         Son Heung-min  23.0  90.0  33.4  83.0  0.000000  80.0
# 629          Jarrod Bowen  12.0  80.0  33.1  83.0  0.000000  80.0

# %%
def Playwell_orgin(trace1):
    x = score_20_orgin[score_20_orgin["Player"] == trace1]
    trace1 = go.Scatterpolar(
      r = [x['G-AC'].values[0], x["Sta"].values[0], x['PKG'].values[0]],
      theta = ['G-AC', "Sta", 'PKG'],
      fill = 'toself',
      name = trace1
    )
    return trace1

def Playwell(trace2):
    x = score_20[score_20["Player"] == trace2]
    trace2 = go.Scatterpolar(
      r = [x['G-AC'].values[0], x["Sta"].values[0], x['PKG'].values[0]],
      theta = ['G-AC', "Sta", 'PKG'],
      fill = 'toself',
      name = trace2
    )
    return trace2
  
def Player_analysis(trace1,trace2):
  trace1 = Playwell_orgin(trace1) 
  trace2 = Playwell(trace2)
  layout = go.Layout(
    xaxis=dict(
          domain=[0, 0.50]
      ),
      yaxis=dict(
           domain=[0, 0.50]
      ),
      xaxis2=dict(
          domain=[0.70, 1]
      ),
       xaxis3=dict(
          domain=[0, 0.50],
          anchor='y3'
      ),
       yaxis2=dict(
          domain=[0, 0.50],
          anchor='x2'
      ),
       yaxis3=dict(
          domain=[0.70, 1]
      ),
    showlegend = True,
     title = "Player"
  )

  data = [trace1, trace2]
  fig = go.Figure(data=data, layout=layout)

  fig.show()

# %%
Player_analysis("Son Heung-min", "Son Heung-min")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cbc53151-aaad-4bf5-9e15-1bc3790316d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbc53151-aaad-4bf5-9e15-1bc3790316d5")) {                    Plotly.newPlot(                        "cbc53151-aaad-4bf5-9e15-1bc3790316d5",                        [{"fill":"toself","name":"Son Heung-min","r":[86.0,86.0,72.0],"theta":["G-AC","Sta","PKG"],"type":"scatterpolar"},{"fill":"toself","name":"Son Heung-min","r":[90.0,83.0,80.0],"theta":["G-AC","Sta","PKG"],"type":"scatterpolar"}],                        {"showlegend":true,"title":{"text":"Player"},"xaxis":{"domain":[0,0.5]},"yaxis":{"domain":[0,0.5]},"xaxis2":{"domain":[0.7,1]},"xaxis3":{"anchor":"y3","domain":[0,0.5]},"yaxis2":{"anchor":"x2","domain":[0,0.5]},"yaxis3":{"domain":[0.7,1]},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie" ...

# %%
Player_analysis("Cristiano Ronaldo", "Cristiano Ronaldo")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b6da5e1e-fd73-4b31-9d4c-a15e36310f5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6da5e1e-fd73-4b31-9d4c-a15e36310f5c")) {                    Plotly.newPlot(                        "b6da5e1e-fd73-4b31-9d4c-a15e36310f5c",                        [{"fill":"toself","name":"Cristiano Ronaldo","r":[86.0,71.0,83.0],"theta":["G-AC","Sta","PKG"],"type":"scatterpolar"},{"fill":"toself","name":"Cristiano Ronaldo","r":[82.0,82.0,89.0],"theta":["G-AC","Sta","PKG"],"type":"scatterpolar"}],                        {"showlegend":true,"title":{"text":"Player"},"xaxis":{"domain":[0,0.5]},"yaxis":{"domain":[0,0.5]},"xaxis2":{"domain":[0.7,1]},"xaxis3":{"anchor":"y3","domain":[0,0.5]},"yaxis2":{"anchor":"x2","domain":[0,0.5]},"yaxis3":{"domain":[0.7,1]},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"typ ...

# %%
Player_analysis("Ivan Toney", "Ivan Toney")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="29876b97-438d-4ab7-9904-12b40408bcc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29876b97-438d-4ab7-9904-12b40408bcc8")) {                    Plotly.newPlot(                        "29876b97-438d-4ab7-9904-12b40408bcc8",                        [{"fill":"toself","name":"Ivan Toney","r":[75.0,74.0,77.0],"theta":["G-AC","Sta","PKG"],"type":"scatterpolar"},{"fill":"toself","name":"Ivan Toney","r":[70.0,82.0,89.0],"theta":["G-AC","Sta","PKG"],"type":"scatterpolar"}],                        {"showlegend":true,"title":{"text":"Player"},"xaxis":{"domain":[0,0.5]},"yaxis":{"domain":[0,0.5]},"xaxis2":{"domain":[0.7,1]},"xaxis3":{"anchor":"y3","domain":[0,0.5]},"yaxis2":{"anchor":"x2","domain":[0,0.5]},"yaxis3":{"domain":[0.7,1]},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"sc ...

# %% [markdown]
# 값을 수정했지만, 큰 차이는 없어 보인다. 그렇다면 상관관계는 어떨까?

# %%
# 상관관계 히트맵 그리기

corrMat = score_20[['90s', 'G-PK', 'G-AC', 'Sta', 'PKG', '%pk']].corr() 
fig, ax = plt.subplots()
fig.set_size_inches(12, 12)
sns.heatmap(corrMat, annot=True)    
ax.set(title='Heatmap of Numerical Data');

# %% [markdown]
# G-PK와 G-AC는 0.96%로 수치가 향상 되었다.
#
# 90s와 Sta는 0.9까지 향상되었다.
#
# %pk와 PKG는 0.88까지 연관있다고 말해준다.

# %% [markdown]
# #결론
#
# 현실 데이터 수치가 높으면, 게임 데이터 수치도 높아야 한다. 우리는 이를 구현하기 위해, 데이터 전처리를 진행했다. 이에 따라, 낮았던 상관관계가 높아지고, 음의 상관관계는 양의 상관관계로 변형 되었다.
#
# 결론적으로 현실 데이터를 게임 속 데이터로 잘 구현했다고 판단된다.
